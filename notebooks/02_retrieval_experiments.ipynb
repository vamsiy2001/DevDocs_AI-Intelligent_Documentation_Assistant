# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[0]  # adjust if needed
# print(PROJECT_ROOT)
sys.path.append(str(PROJECT_ROOT))

# %%
from src.retrieval.hybrid_search import HybridRetriever

# Initialize
retriever = HybridRetriever()
retriever.load_vector_store()

# Test query
results = retriever.hybrid_search("How to use LangChain agents?")

# Analyze results
for i, result in enumerate(results, 1):
    print(f"\n{i}. Score: {result['score']:.3f}")
    print(f"Content: {result['content'][:200]}...")
# Out:
# 🚀 Initializing Hybrid Retriever (100% FREE)...
# 📊 Loading embedding model (local, no API cost)...
# /Users/yvk/Documents/projects/devdocs-ai/src/retrieval/hybrid_search.py:29: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embeddings = HuggingFaceEmbeddings(**EMBEDDING_CONFIG)
# 🎯 Loading reranker model (local, no API cost)...
# ✅ Hybrid Retriever ready!
# /Users/yvk/Documents/projects/devdocs-ai/src/retrieval/hybrid_search.py:49: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   self.vector_store = Chroma(
# ✅ Loaded vector store from ./data/chroma_db
# 📊 Retrieved 0 dense + 0 sparse = 0 unique docs
# 🎯 Reranked to top 0 documents
